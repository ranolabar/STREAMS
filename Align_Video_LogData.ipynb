# %%
from moviepy.editor import *
import pandas as pd
import numpy as np
import datetime

logfile = input("Filename (Tab-Delimited Log File): ")
myFile = pd.read_table(logfile,sep='\t')
list(myFile)
time_colname = input("Name of Timestamp Column: ")
myFile['Time'] = pd.to_datetime(myFile[time_colname])

myFile.head()
# Out:
# Filename (Tab-Delimited Log File): ChemData_ForStreams_FINAL.txt
# Name of Timestamp Column: Time
#      Student      Date                Time  Activity            Screen  \
# 0  aarcri001  10/16/15 2016-10-10 04:46:36         3     massHydroxide
# 1  aarcri001  10/16/15 2016-10-10 04:46:36         3     massHydroxide
# 2  aarcri001  10/16/15 2016-10-10 04:47:22         3  molMassCopperHyd
# 3  aarcri001  10/16/15 2016-10-10 04:47:22         3  molMassCopperHyd
# 4  aarcri001  10/16/15 2016-10-10 04:49:28         3         molRatios
#
#           Event               KC
# 0  cu_mass_corr  Experimentation
# 1       sig_fig         Sig.Figs
# 2       mmatoms         Mol.Mass
# 3      numatoms         Mol.Mass
# 4     molRatios         Bal.Rxns

# %%
alignfile = input("Filename (Temporal Alignment of New Streams): ")
numstreams = int(input("How many new streams are there?: "))
align_info = pd.read_table(alignfile,sep='\t')
align_columns = list(align_info)
select_constraints = align_columns[0:(len(align_columns)-3*numstreams)]

align_info
# Out:
# Filename (Temporal Alignment of New Streams): ChemData_ForStreams_Align.txt
# How many new streams are there?: 1
#       Student      Date                S1.Filename  S1.Min  S1.Sec
# 0   aarcri001  10/16/15   10_16_2015_aarcri001.mp4       0      56
# 1   adiper001  10/16/15   10_16_2015_adiper001.mp4       2      52
# 2   alearc001  10/16/15   10_16_2015_alearc001.mp4       0      53
# 3   alegie001  10/16/15   10_16_2015_alegie001.mp4       1      20
# 4   aleher007  10/16/15   10_16_2015_aleher007.mp4       5      48
# 5   annpan001  10/16/15   10_16_2015_annpan001.mp4       1      56
# 6   benmin001  10/16/15   10_16_2015_benmin001.mp4      10      49
# 7   brawag001  10/16/15   10_16_2015_brawag001.mp4       3      59
# 8   bridug001  10/16/15   10_16_2015_bridug001.mp4       4       7
# 9   chehav001  10/16/15   10_16_2015_chehav001.mp4       2      56
# 10  chrshi001  10/16/15   10_16_2015_chrshi001.mp4       1      37
# 11  davpan001  10/16/15   10_16_2015_davpan001.mp4       0      32
# 12  dincon001  10/16/15   10_16_2015_dincon001.mp4       0      31
# 13  domcor001  10/16/15   10_16_2015_domcor001.mp4       2      49
# 14  elahun001  10/16/15   10_16_2015_elahun001.mp4       2      47
# 15  gradie001  10/16/15   10_16_2015_gradie001.mp4       2      52
# 16  hanbut001  10/16/15   10_16_2015_hanbut001.mp4       2      40
# 17  jascas001  10/16/15   10_16_2015_jascas001.mp4       0      54
# 18  joswas001  10/16/15   10_16_2015_joswas001.mp4       6      48
# 19  julkna001  10/16/15   10_16_2015_julkna001.mp4       2      39
# 86  vichar001  10/26/15   10_26_2015_vichar001.mp4       5      29
# 87  zaczap001  10/26/15   10_26_2015_zaczap001.mp4       5      52
#
# [88 rows x 5 columns]

# %%
def find_start_time (row, column):
    end_time = row[column]
    times = selection[selection[column] < end_time][column]
    if len(times)==0:
        return 0
    return max(times)

def find_total_seconds(row, column):
    if row[column]==0: return 0
    return row[column].total_seconds()

master = pd.DataFrame()
    
for index, row in align_info.iterrows():
    
    selection = myFile.loc[(myFile.Student == row['Student']) & (myFile.Date == row['Date'])]
        
    for s in range(1,numstreams+1):
    
        prefix = str(align_columns[len(align_columns)-3*s]).split(".")[0]

        stream_file = row[len(align_columns)-3*s]
        mins = row[len(align_columns)-3*s+1]
        secs = row[len(align_columns)-3*s+2]
        print(prefix + ': ' + stream_file + ' ' + str(mins) + ':' + str(secs))

        selection[str(prefix+'.Filename')]=str(stream_file)
        selection[str(prefix+'.VideoTimeEnd')]=selection.Time-selection.Time.iloc[0]+datetime.timedelta(minutes=mins,seconds=secs)
        selection[str(prefix+'.VideoTimeEnd_sec')]=selection.apply(lambda row:find_total_seconds(row,str(prefix+'.VideoTimeEnd')),axis=1)
        selection[str(prefix+'.VideoTimeStart_sec')] = selection.apply(lambda row: find_start_time(row,str(prefix+'.VideoTimeEnd_sec')), axis=1)
        selection = selection.drop(str(prefix+'.VideoTimeEnd'), 1)

    #selection.to_csv(str(stream_file + '.txt'), sep='\t') ## writes out a text file for each selection
    master2 = master.copy() ## adds each selection to master data frame
    master = master2.append(selection)

master.head()
# Out:
# S1: 10_16_2015_aarcri001.mp4 0:56
# S1: 10_16_2015_adiper001.mp4 2:52
# S1: 10_16_2015_alearc001.mp4 0:53
# S1: 10_16_2015_alegie001.mp4 1:20
# S1: 10_16_2015_aleher007.mp4 5:48
# S1: 10_16_2015_annpan001.mp4 1:56
# S1: 10_16_2015_benmin001.mp4 10:49
# S1: 10_16_2015_brawag001.mp4 3:59
# S1: 10_16_2015_bridug001.mp4 4:7
# S1: 10_16_2015_chehav001.mp4 2:56
# S1: 10_16_2015_chrshi001.mp4 1:37
# S1: 10_16_2015_davpan001.mp4 0:32
# S1: 10_16_2015_dincon001.mp4 0:31
# S1: 10_16_2015_domcor001.mp4 2:49
# S1: 10_16_2015_elahun001.mp4 2:47
# S1: 10_16_2015_gradie001.mp4 2:52
# S1: 10_16_2015_hanbut001.mp4 2:40
# S1: 10_16_2015_jascas001.mp4 0:54
# S1: 10_16_2015_joswas001.mp4 6:48
# S1: 10_16_2015_julkna001.mp4 2:39
# S1: 10_16_2015_karmil001.mp4 2:48
# S1: 10_16_2015_katpor001.mp4 2:26
# S1: 10_16_2015_keloto001.mp4 1:47
# S1: 10_16_2015_krilan001.mp4 6:57
# S1: 10_16_2015_lukecav001.mp4 2:44
# S1: 10_16_2015_lydmil001.mp4 0:42
# S1: 10_26_2015_sarnar001.mp4 1:43
# S1: 10_26_2015_shahar001.mp4 4:40
# S1: 10_26_2015_sharos002.mp4 4:32
# S1: 10_26_2015_stosch001.mp4 2:41
# S1: 10_26_2015_talbow001.mp4 7:14
# S1: 10_26_2015_vichar001.mp4 5:29
# S1: 10_26_2015_zaczap001.mp4 5:52
#        Student      Date                Time  Activity            Screen  \
# 174  aarcri001  10/16/15 2016-10-10 04:50:34         3     amountReacted
# 220  aarcri001  10/16/15 2016-10-10 04:50:34         3     amountReacted
# 257  aarcri001  10/16/15 2016-10-10 04:50:34         3     amountReacted
# 264  aarcri001  10/16/15 2016-10-10 04:59:41         3  calcReactedBaSO4
# 324  aarcri001  10/16/15 2016-10-10 04:59:41         3  calcReactedBaSO4
#
#         Event        KC               S1.Filename  S1.VideoTimeEnd_sec  \
# 174    amount  Bal.Rxns  10_16_2015_aarcri001.mp4                 56.0
# 220   molMass  Mol.Mass  10_16_2015_aarcri001.mp4                 56.0
# 257  molRatio  Bal.Rxns  10_16_2015_aarcri001.mp4                 56.0
# 264    amount  Bal.Rxns  10_16_2015_aarcri001.mp4                603.0
# 324   molMass  Mol.Mass  10_16_2015_aarcri001.mp4                603.0
#
#      S1.VideoTimeStart_sec
# 174                  -10.0
# 220                  -10.0
# 257                  -10.0
# 264                  557.0
# 324                  557.0

# %%
def find_start_time (row, column):
    end_time = row[column]
    times = selection[selection[column] < end_time][column]
    if len(times)==0:
        return 0
    return max(times)

def find_total_seconds(row, column):
    if row[column]==0: return 0
    return row[column].total_seconds()

selection = myFile.loc[(myFile.Student == 'aarcri001') & (myFile.Date == '10/16/15')]
          
prefix = 'S1'
mins = 0
secs = 56

selection[str(prefix+'.Filename')]='aarcri001.mp4'
selection[str(prefix+'.VideoTimeEnd')]=selection.Time-selection.Time.iloc[0]+datetime.timedelta(minutes=mins,seconds=secs)
selection.Time
# Out:
# 174    2016-10-10 04:50:34
# 220    2016-10-10 04:50:34
# 257    2016-10-10 04:50:34
# 264    2016-10-10 04:59:41
# 324    2016-10-10 04:59:41
# 340    2016-10-10 04:59:41
# 693    2016-10-10 04:46:36
# 704    2016-10-10 04:46:36
# 748    2016-10-10 04:58:55
# 774    2016-10-10 04:58:55
# 827    2016-10-10 04:47:22
# 861    2016-10-10 04:47:22
# 885    2016-10-10 04:49:28
# 905    2016-10-10 04:49:28
# 959    2016-10-10 04:56:46
# 1025   2016-10-10 04:51:17
# 1059   2016-10-10 04:58:31
# 1077   2016-10-10 04:58:31
# 1122   2016-10-10 04:58:31
# 1287   2016-10-10 05:01:15
# 1322   2016-10-10 05:01:15
# 1363   2016-10-10 05:01:15
# 1401   2016-10-10 05:01:15
# Name: Time, dtype: datetime64[ns]

# %%
master.to_csv('ChemData_StreamsAligned.txt', sep='\t')
